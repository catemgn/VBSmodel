# %% [markdown]
# # Figure 9 paper

# %%
from plots import makefigure9

# %% [markdown]
# # Figure 10 paper

# %%
from plots import makefigure10

# %% [markdown]
# # Figure 11 paper

# %%
from plots import makefigure11
